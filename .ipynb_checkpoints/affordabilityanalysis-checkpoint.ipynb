# %% [markdown]
# ##### According to a new study from Princeton University's Woodrow Wilson School,  no matter how much more than $75,000 people make, they don't report any greater degree of happiness (http://content.time.com/time/magazine/article/0,9171,2019628,00.html).
#
# ##### Therefore, in our analysis, we concentrated on metropolitan areas with a median income of $75,000 or more and considered which of these cities would be more affordable based on price per income.
#
# #### We've reviewed rent, sale prices of homes, income and price per square foot

# %%
# Dependencies and Setup
import requests
import json
import codecs
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import matplotlib as mpl
import gmaps
import gmaps.datasets
from ipywidgets.embed import embed_minimal_html

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# print(gkey)

# %%
# File to Load
price_csv = "Resources/PricePSQ.csv"
affordability_csv = "Resources/affordability_income.csv"
#regionID (used as primary key in other instances) is different in rental_data.csv
rental_csv = "Resources/rental_data.csv"
price_income_csv = "Resources/price_to_income.csv"

# %%
# Read Affordability Data
pricing_data = pd.read_csv(price_csv, encoding = "ISO-8859-1")
afford_data = pd.read_csv(affordability_csv, encoding = "ISO-8859-1")
rental_data = pd.read_csv(rental_csv, encoding = "ISO-8859-1")
price_income_data = pd.read_csv(price_income_csv, encoding = "ISO-8859-1")

# %%
#Find the cities with median income of 75000 (based on Princeton's study) or greater per family and clean the data 
#This dataframe will only show the income data for December of each year 
#Data shown is from 2010-2018
good_income = afford_data.loc[afford_data["2018-03"] >= 75000, \
              ["RegionID", "RegionName", "2010-03", "2011-03", "2012-03", "2013-03", \
               "2014-03", "2015-03", "2016-03", "2017-03", "2018-03"]]

#Print the top income cities
good_income.sort_values(by=['2018-03'], ascending=False)
# Out:
#      RegionID                     RegionName   2010-03   2011-03   2012-03  \
# 34     395059                   San Jose, CA  83870.93  85531.04  87031.24
# 11     395057              San Francisco, CA  72999.45  73138.14  73940.77
# 7      395209                 Washington, DC  86548.90  87700.10  88766.74
# 58     394415                   Stamford, CT  79839.31  79087.63  80136.44
# 297    394900                       Napa, CA  66492.32  65975.29  66280.66
# 10     394404                     Boston, MA  68693.52  69400.70  70262.70
# 66     394952                    Ventura, CA  75558.47  75265.73  75500.17
# 15     395078                    Seattle, WA  63553.48  64249.95  64521.82
# 105    395068                 Santa Rosa, CA  62509.88  62117.14  61408.42
# 162    394405                    Boulder, CO  63793.22  65265.91  67588.54
# 54     753924             Urban Honolulu, HI  70425.65  70639.84  71323.83
# ...

# %%
#Set x axis and tick locations
x_axis = np.arange(len(good_income))
tick_locations = [value+0.4 for value in x_axis]

#Create a list indicating where to write x labels and set figure size to
plt.figure(figsize=(13,6))
plt.bar(x_axis, (good_income["2018-03"]), color="skyblue", alpha=1, align="edge")
plt.xticks(tick_locations, good_income["RegionName"], rotation="vertical")

#Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, (max(good_income["2018-03"])+5000))

#Set a Titile and labels
plt.title("Average Median Income per Household per City")
plt.xlabel("List of Cities")
plt.ylabel("Income Level")

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\AverageMedianPerCity.png", bbox_inches="tight")

#Add Grid
plt.grid(alpha = 0.3)

# %% [markdown]
# ### Price to Income for cities where income is greater than 75K

# %%
# Merge the income and housing price on RegionID
price_to_income = pd.merge(good_income, price_income_data, on='RegionID', how='left')

# PFilter the rows for which the column Index is "Price To Income"
income = price_to_income[price_to_income['Index'] == 'Price To Income']

# Pull the columns shown below and delete the rest
march_income = income[["RegionID", "RegionName_x", "2010_03", "2011_03", "2012_03", "2013_03", "2014_03", "2015_03", "2016_03", "2017_03", "2018_03"]]

# Change the name of the column
march_income_clean = march_income.rename(columns={"RegionName_x": "RegionName"})

# Sort the income data by year 2018 
march_income_clean.sort_values(by=['2018_03'], ascending=False).head()
# Out:
#     RegionID          RegionName   2010_03   2011_03   2012_03   2013_03  \
# 58    395065      Santa Cruz, CA  8.283408  7.675891  7.197588  7.716812
# 27    395059        San Jose, CA  6.944003  6.542654  6.414938  7.236039
# 9     395057   San Francisco, CA  7.248000  6.733833  6.415946  7.176791
# 33    753924  Urban Honolulu, HI  6.687904  6.722835  6.655560  6.753525
# 61    394731         Kahului, HI  6.765090  6.384182  5.892622  6.034405
#
#      2014_03   2015_03   2016_03   2017_03    2018_03
# 58  8.886340  9.532659  9.551430  9.830453  10.093040
# 27  8.022476  8.462236  8.684795  8.798078   9.993398
# 9   8.099977  8.353154  8.524281  8.564542   8.864445
# 33  7.225041  7.325037  7.569094  8.009257   8.191807
# 61  6.694787  7.197414  7.239739  7.436942   7.826431

# %% [markdown]
# ### Rent to Income for cities where income is greater than 75K

# %%
# Merge the income and housing price on RegionID
rent_to_income = pd.merge(good_income, price_income_data, on='RegionID', how='left')

# Filter the rows for which the column Index is "Rent Affordability"
rent = price_to_income[price_to_income['Index'] == 'Rent Affordability']

# Filter the columns and show only the columns below
march_rent = rent[["RegionID", "RegionName_x", "2011_03", "2012_03", "2013_03", "2014_03", "2015_03", "2016_03", "2017_03", "2018_03"]]

# Change the name of the row "Region Name" 
march_rent_clean = march_rent.rename(columns={"RegionName_x": "RegionName"})

# Sort the Rent Affordibility data by year 2018
march_rent_clean.sort_values(by=['2018_03'], ascending=False).head()
# Out:
#     RegionID         RegionName   2011_03   2012_03   2013_03   2014_03  \
# 60    395065     Santa Cruz, CA  0.378978  0.382593  0.388840  0.373962
# 41    395068     Santa Rosa, CA  0.340196  0.338064  0.344411  0.360477
# 11    395057  San Francisco, CA  0.377696  0.382198  0.368085  0.379624
# 19    395056      San Diego, CA  0.392414  0.397406  0.385960  0.398791
# 1     394913       New York, NY  0.363721  0.367102  0.364429  0.386650
#
#      2015_03   2016_03   2017_03   2018_03
# 60  0.446843  0.461148  0.446597  0.439384
# 41  0.390388  0.405240  0.391123  0.402158
# 11  0.417520  0.426876  0.402056  0.387872
# 19  0.404298  0.401531  0.394516  0.387446
# 1   0.404256  0.404667  0.385103  0.369670

# %% [markdown]
# ### Mortgage to Income for cities where income is greater than 75K

# %%
# Mortgage Affordability Data
# In New York, for example, the mortgage payment is 26% of total income for 2018-03. 
# However, this is just the mortgage payment and does not include taxes, insurance and other expenses related to home ownership

# Merge the income and housing price on RegionID
mortgage_to_income = pd.merge(good_income, price_income_data, on='RegionID', how='left')

# Filter the rows for which the column Index is "Mortgage Affordability"
mortgage = mortgage_to_income[mortgage_to_income['Index'] == 'Mortgage Affordability']

# Filter the columns and show only the columns below
march_mortgage = mortgage[["RegionID", "RegionName_x", "2010_03", "2011_03", "2012_03", "2013_03", "2014_03", "2015_03", "2016_03", "2017_03", "2018_03"]]

# Change the name of the row "Region Name" 
march_mortgage_clean = march_mortgage.rename(columns={"RegionName_x": "RegionName"})

# Sort the Mortgage Affordibility data by year 2018
march_mortgage_clean.sort_values(by=['2018_03'], ascending=False).head()
# Out:
#     RegionID          RegionName   2010_03   2011_03   2012_03   2013_03  \
# 59    395065      Santa Cruz, CA  0.425428  0.388402  0.327890  0.335560
# 28    395059        San Jose, CA  0.356637  0.331060  0.292236  0.314654
# 10    395057   San Francisco, CA  0.372250  0.340734  0.292282  0.312078
# 34    753924  Urban Honolulu, HI  0.343484  0.340177  0.303198  0.293672
# 62    394731         Kahului, HI  0.347448  0.323041  0.268442  0.262402
#
#      2014_03   2015_03   2016_03   2017_03   2018_03
# 59  0.424175  0.424853  0.421532  0.461497  0.487495
# 28  0.382940  0.377146  0.383285  0.413031  0.482683
# 10  0.386640  0.372284  0.376201  0.402068  0.428154
# 34  0.344876  0.326463  0.334046  0.376000  0.395665
# 62  0.319565  0.320775  0.319511  0.349132  0.378018

# %% [markdown]
# ### Top 5 cities with income higher than 75K

# %%
# Income Greater than $75K, top 5 by City
top5_income = good_income.sort_values(by=['2018-03'], ascending=False).head()
top5_income.round(2)

# Change the name of the columns
clean_top5_income = top5_income.rename(columns={"2010-03" : "2010 Income", "2011-03" : "2011 Income", \
                           "2012-03" : "2012 Income", "2013-03" : "2013 Income", \
                           "2014-03" : "2014 Income", "2015-03" : "2015 Income", \
                           "2016-03" : "2016 Income", "2017-03" : "2017 Income", \
                           "2018-03" : "2018 Income"})

# Set Index
index_top5_income = clean_top5_income.set_index("RegionName")

index_top5_income

# Filter the data for top 5 cities with highest income
# Filter the Data for San Jose
sanjose_income = index_top5_income.loc["San Jose, CA", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# Fitler the Data for San Francisco
sanfran_income = index_top5_income.loc["San Francisco, CA", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# Filer the data for Washington, DC
washington_income = index_top5_income.loc["Washington, DC", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# Filter the data for Stamford 
stamford_income = index_top5_income.loc["Stamford, CT", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# Filter the data for Napa
napa_income = index_top5_income.loc["Napa, CA", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# add years 2010-2018 in a list
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# Plot for top 5 cities with highest income 
plt.plot(years, sanjose_income, color= 'green', label = "San Jose, CA")
plt.plot(years, sanfran_income, color= 'blue', label = "San Francisco, CA")
plt.plot(years, washington_income, color= 'red', label = "Washnigton, DC")
plt.plot(years, stamford_income, color= 'pink', label = "Stamford, CT")
plt.plot(years, napa_income, color= 'purple', label = "Napa, CA")

# Add legend
plt.legend(loc="best")

#Add graph title, x and y label and set y limits 
plt.title("Top 5 Cities with Highest Income 2010-2018")
plt.ylim(52000, (max(good_income["2018-03"])+5000))
plt.xlabel("Years")
plt.ylabel("Income Level")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\Top5Cities_Income.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Bottom 5 cities with income higher than 75K

# %%
# Income Greater than $75K, bottom 5 by City
bottom5_income = good_income.sort_values(by=['2018-03'], ascending=True).head()
bottom5_income.round(2)

# Change the name of the columns
clean_bottom5_income = bottom5_income.rename(columns={"2010-03" : "2010 Income", "2011-03" : "2011 Income", \
                           "2012-03" : "2012 Income", "2013-03" : "2013 Income", \
                           "2014-03" : "2014 Income", "2015-03" : "2015 Income", \
                           "2016-03" : "2016 Income", "2017-03" : "2017 Income", \
                           "2018-03" : "2018 Income"})

# Set Index
index_bottom5_income = clean_bottom5_income.set_index("RegionName")

index_bottom5_income

# Filter the data for bottom 5 cities with highest income
# Filter the Data for Austin
austin_income = index_bottom5_income.loc["Austin, TX", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# Filter the Data for Midland
midland_income = index_bottom5_income.loc["Midland, TX", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# Filter the Data for Anchorage
anchorage_income = index_bottom5_income.loc["Anchorage, AK", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# Filter the Data for New York
newyork_income = index_bottom5_income.loc["New York, NY", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]

# Filter the Data for Kahului
kahului_income = index_bottom5_income.loc["Kahului, HI", ["2010 Income", "2011 Income", "2012 Income", \
                                "2013 Income", "2014 Income", "2015 Income", \
                                "2016 Income", "2017 Income", "2018 Income"]]


#Plot Graphs
plt.plot(years, austin_income, color= 'green', label = "Austin, TX")
plt.plot(years, midland_income, color= 'blue', label = "Midland, TX")
plt.plot(years, anchorage_income, color= 'red', label = "Anchorage, AK")
plt.plot(years, newyork_income, color= 'pink', label = "New York, NY")
plt.plot(years, kahului_income, color= 'purple', label = "Kahului, HI")

plt.legend(loc="best")

#Add graph title, x and y label and set y limits 
plt.title("Bottom 5 Cities with Highest Income 2010-2018")
plt.ylim(52000, (max(good_income["2018-03"])+5000))
plt.xlabel("Years")
plt.ylabel("Income Level")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\Bottom5CitiesIncome", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Housing Price to Income Ratio for Top 5 (Least Affordable) Cities with Income Level Greater than 75K or More

# %%
# Purchase/Sale Price of Home, top 5 by City (Most Expensive)
# In Santa Cruz, CA, sale prices of homes are 10 times that of the average income
top5_housing_ratio = march_income_clean.sort_values(by=['2018_03'], ascending=False).head()
top5_housing_ratio.round(2)

# Change the name of the columns
clean_top5_housing_ratio = top5_housing_ratio.rename(columns={"2010_03" : "2010 Ratio", "2011_03" : "2011 Ratio", \
                           "2012_03" : "2012 Ratio", "2013_03" : "2013 Ratio", \
                           "2014_03" : "2014 Ratio", "2015_03" : "2015 Ratio", \
                           "2016_03" : "2016 Ratio", "2017_03" : "2017 Ratio", \
                           "2018_03" : "2018 Ratio"})

clean_top5_housing_ratio

#Set Index
index_top5_housing_ratio = clean_top5_housing_ratio.set_index("RegionName")

index_top5_housing_ratio

# Filter the data for top 5 cities with highest Price to Income Ratio
# Filter the Data for Santa Cruz
santacruz_housing_ratio = index_top5_housing_ratio.loc["Santa Cruz, CA", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

# Filter the Data for San Jose
sanjose_housing_ratio = index_top5_housing_ratio.loc["San Jose, CA", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

# Filter the Data for San Fransisco
sanfran_housing_ratio = index_top5_housing_ratio.loc["San Francisco, CA", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

# Filter the Data for Honolulu
honolulu_housing_ratio = index_top5_housing_ratio.loc["Urban Honolulu, HI", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

# Filter the Data for Kahului
kahului_housing_ratio = index_top5_housing_ratio.loc["Kahului, HI", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

index_top5_housing_ratio

#Plot Graphs
plt.plot(years, santacruz_housing_ratio, color= 'green', label = "Santa Cruz, CA")
plt.plot(years, sanjose_housing_ratio, color= 'blue', label = "San Jose, CA")
plt.plot(years, sanfran_housing_ratio, color= 'red', label = "San Francisco, CA")
plt.plot(years, honolulu_housing_ratio, color= 'pink', label = "Honolulu, HI")
plt.plot(years, kahului_housing_ratio, color= 'purple', label = "Kahului, HI")

plt.legend(loc="best")

#Add graph title, x and y label and set y limits 
plt.title("Least Affordable Cities to Buy a House 2010-2018")
plt.ylim((min(clean_top5_housing_ratio["2018 Ratio"])-2), (max(clean_top5_housing_ratio["2018 Ratio"])+1))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\LeastAffordable_Buy.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Housing Price to Income Ratio for Bottom 5 (Most Affordable) Cities with Income Level Greater than 75K or More

# %%
# Purchase/Sale Price of Home, bottom 5 by City (Least Expensive)
# In Midland, TX, sales prices of homes are 2.8 times that of the average income
bottom5_housing_ratio = march_income_clean.sort_values(by=['2018_03'], ascending=True).head()
bottom5_housing_ratio.round(2)

# Change the name of the columns-bottom5_ratio
clean_bottom5_housing_ratio = bottom5_housing_ratio.rename(columns={"2010_03" : "2010 Ratio", "2011_03" : "2011 Ratio", \
                           "2012_03" : "2012 Ratio", "2013_03" : "2013 Ratio", \
                           "2014_03" : "2014 Ratio", "2015_03" : "2015 Ratio", \
                           "2016_03" : "2016 Ratio", "2017_03" : "2017 Ratio", \
                           "2018_03" : "2018 Ratio"})

clean_bottom5_housing_ratio

#Set Index
index_bottom5_housing_ratio = clean_bottom5_housing_ratio.set_index("RegionName")

index_bottom5_housing_ratio 
# Filter the data for bottom 5 cities with highest Price to Income Ratio
# Filter the Data for Midland
midland_housing_ratio = index_bottom5_housing_ratio.loc["Midland, TX", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

# Filter the Data for Trenton
trenton_housing_ratio = index_bottom5_housing_ratio.loc["Trenton, NJ", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

# Filter the Data for Fairbanks
fairbanks_housing_ratio = index_bottom5_housing_ratio.loc["Fairbanks, AK", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

# Filter the Data for Minneapolis
minneapolis_housing_ratio = index_bottom5_housing_ratio.loc["Minneapolis-St Paul, MN", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

# Filter the Data for California-Lexington Park
cal_lex_housing_ratio = index_bottom5_housing_ratio.loc["California-Lexington Park, MD", ["2010 Ratio", "2011 Ratio", "2012 Ratio", \
                                "2013 Ratio", "2014 Ratio", "2015 Ratio", \
                                "2016 Ratio", "2017 Ratio", "2018 Ratio"]]

index_bottom5_housing_ratio

# Plot Graphs
plt.plot(years, midland_housing_ratio, color= 'green', label = "Midland, TX")
plt.plot(years, trenton_housing_ratio, color= 'blue', label = "Trenton, NJ")
plt.plot(years, fairbanks_housing_ratio, color= 'red', label = "Fairbanks, AK")
plt.plot(years, minneapolis_housing_ratio, color= 'pink', label = "Minneapolis-St Paul, MN")
plt.plot(years, cal_lex_housing_ratio, color= 'purple', label = "California-Lexington Park, MD")

plt.legend(loc="best")

#Add graph title, x and y label and set y limits 
plt.title("Most Affordable Cities to Buy a House 2010-2018")
plt.ylim((min(clean_bottom5_housing_ratio["2018 Ratio"])-1), (max(clean_bottom5_housing_ratio["2018 Ratio"])+1.5))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\MostAffordable_Buy.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Rent to Income Ratio for Top 5 (Least Affordable) Cities with Income Level Greater than 75K or More

# %%
# Rent Price of Home, top 5 by City (Most Expensive)
# In Santa Cruz, CA, Rent Price of homes are 44% times that of the average income
top5_rent = march_rent_clean.sort_values(by=['2018_03'], ascending=False).head()
top5_rent.round(2)

# Change the name of the columns-top5_ratio
clean_top5_rent = top5_rent.rename(columns={"2010_03" : "2010 Rent to Income Ratio", "2011_03" : "2011 Rent to Income Ratio", \
                           "2012_03" : "2012 Rent to Income Ratio", "2013_03" : "2013 Rent to Income Ratio", \
                           "2014_03" : "2014 Rent to Income Ratio", "2015_03" : "2015 Rent to Income Ratio", \
                           "2016_03" : "2016 Rent to Income Ratio", "2017_03" : "2017 Rent to Income Ratio", \
                           "2018_03" : "2018 Rent to Income Ratio"})


clean_top5_rent.round(2)

#Set Index
index_top5_rent = clean_top5_rent.set_index("RegionName")

index_top5_rent.round(2)

# Filter the data for top 5 cities with highest Rent to Income Ratio
# Filter the Data for Santa Cruz
santacruz_rent_ratio = index_top5_rent.loc["Santa Cruz, CA", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

# Filter the Data for Santa Rosa
santarosa_rent_ratio = index_top5_rent.loc["Santa Rosa, CA", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

# Filter the Data for San Francisco
sanfran_rent_ratio = index_top5_rent.loc["San Francisco, CA", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

# Filter the Data for San Diego
sandiego_rent_ratio = index_top5_rent.loc["San Diego, CA", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

# Filter the Data for New York
newyork_rent_ratio = index_top5_rent.loc["New York, NY", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

index_top5_rent.round(2)

#Plot Graphs
plt.plot(years, santacruz_rent_ratio, color= 'green', label = "Santa Cruz, CA")
plt.plot(years, santarosa_rent_ratio, color= 'blue', label = "Santa Rosa, CA")
plt.plot(years, sanfran_rent_ratio, color= 'red', label = "San Francisco, CA")
plt.plot(years, sandiego_rent_ratio, color= 'pink', label = "San Diego, CA")
plt.plot(years, newyork_rent_ratio, color= 'purple', label = "New York, NY")

plt.legend(loc="best")

#Add graph title, x and y label and set y limits 
plt.title("Least Affordable Cities to Rent a House 2010-2018")
plt.ylim((min(clean_top5_rent["2018 Rent to Income Ratio"])-.1), (max(clean_top5_rent["2018 Rent to Income Ratio"])+.1))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\LeastAffordableRent.png", bbox_inches="tight")

plt.show
# Out:
# C:\Users\anoos\Anaconda3\lib\site-packages\pandas\core\indexing.py:1017: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Rent to Income Ratio for bottom 5 (Most Affordable) Cities with Income Level Greater than 75K or More

# %%
# Rent Price of Home, bottom 5 by City (Least Expensive)
# In Minneapolis, CA, Rent Price of homes are 25% times that of the average income
bottom5_rent = march_rent_clean.sort_values(by=['2018_03'], ascending=True).head()
bottom5_rent.round(2)

# Change the name of the columns-bottom5_ratio
clean_bottom5_rent = bottom5_rent.rename(columns={"2010_03" : "2010 Rent to Income Ratio", "2011_03" : "2011 Rent to Income Ratio", \
                           "2012_03" : "2012 Rent to Income Ratio", "2013_03" : "2013 Rent to Income Ratio", \
                           "2014_03" : "2014 Rent to Income Ratio", "2015_03" : "2015 Rent to Income Ratio", \
                           "2016_03" : "2016 Rent to Income Ratio", "2017_03" : "2017 Rent to Income Ratio", \
                           "2018_03" : "2018 Rent to Income Ratio"})

clean_bottom5_rent.round(2)

#Set Index
index_bottom5_rent = clean_bottom5_rent.set_index("RegionName")

index_bottom5_rent.round(2)

# Filter the data for bottom 5 cities with highest Rent to Income Ratio
# Filter the Data for Minneapolis
minneapolis_rent_ratio = index_bottom5_rent.loc["Minneapolis-St Paul, MN", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

# Filter the Data for Washington
washington_rent_ratio = index_bottom5_rent.loc["Washington, DC", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

# Filter the Data for Fairbanks
fairbanks_rent_ratio = index_bottom5_rent.loc["Fairbanks, AK", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

# Filter the Data for Manchester
manchester_rent_ratio = index_bottom5_rent.loc["Manchester, NH", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

# Filter the Data for Baltimore
baltimore_rent_ratio = index_bottom5_rent.loc["Baltimore, MD", ["2010 Rent to Income Ratio", "2011 Rent to Income Ratio", "2012 Rent to Income Ratio", \
                                "2013 Rent to Income Ratio", "2014 Rent to Income Ratio", "2015 Rent to Income Ratio", \
                                "2016 Rent to Income Ratio", "2017 Rent to Income Ratio", "2018 Rent to Income Ratio"]]

index_bottom5_rent.round(2)
# Plot Graphs
plt.plot(years, minneapolis_rent_ratio, color= 'green', label = "Minneapolis-St Paul, MN")
plt.plot(years, washington_rent_ratio, color= 'blue', label = "Washington, DC")
plt.plot(years, fairbanks_rent_ratio, color= 'red', label = "Fairbanks, AK")
plt.plot(years, manchester_rent_ratio, color= 'pink', label = "Manchester, NH")
plt.plot(years, baltimore_rent_ratio, color= 'purple', label = "Baltimore, MD")

plt.legend(loc="best")

#Add graph title, x and y label and set y limits
plt.title("Most Affordable Cities to Rent a House 2010-2018")
plt.ylim((min(clean_bottom5_rent["2018 Rent to Income Ratio"])-.1), (max(clean_bottom5_rent["2018 Rent to Income Ratio"])+.1))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\MostAffordableRent.png", bbox_inches="tight")

plt.show
# Out:
# C:\Users\anoos\Anaconda3\lib\site-packages\pandas\core\indexing.py:1017: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Mortgage to Income Ratio for top 5 (Least Affordable) Cities with Income Level Greater than 75K or More

# %%
# Mortgage to Income Ratio, top 5 by City (Most Expensive)
# In Santa Cruz, Mortgage Payment of homes are 49% of the average income
top5_mortgage = march_mortgage_clean.sort_values(by=['2018_03'], ascending=False).head()

top5_mortgage.round(2)

# Change the name of the columns-top5_ratio
clean_top5_mortgage = top5_mortgage.rename(columns={"2010_03" : "2010 Mortgage to Income Ratio", "2011_03" : "2011 Mortgage to Income Ratio", \
                           "2012_03" : "2012 Mortgage to Income Ratio", "2013_03" : "2013 Mortgage to Income Ratio", \
                           "2014_03" : "2014 Mortgage to Income Ratio", "2015_03" : "2015 Mortgage to Income Ratio", \
                           "2016_03" : "2016 Mortgage to Income Ratio", "2017_03" : "2017 Mortgage to Income Ratio", \
                           "2018_03" : "2018 Mortgage to Income Ratio"})

clean_top5_mortgage.round(2)

# Set Index
index_top5_mortgage = clean_top5_mortgage.set_index("RegionName")

index_top5_mortgage.round(2)

# Filter the data for top 5 cities with highest Mortgage to Income Ratio
# Filter the Data for Santa Cruz
santacruz_mortgage_ratio = index_top5_mortgage.loc["Santa Cruz, CA", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

# Filter the Data for San Jose
sanjose_mortgage_ratio = index_top5_mortgage.loc["San Jose, CA", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

# Filter the Data for San Francisco
sanfran_mortgage_ratio = index_top5_mortgage.loc["San Francisco, CA", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

# Filter the Data for Honolulu
honolulu_mortgage_ratio = index_top5_mortgage.loc["Urban Honolulu, HI", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

# Filter the Data for Kahului
kahului_mortgage_ratio = index_top5_mortgage.loc["Kahului, HI", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

index_top5_mortgage.round(2)

#Plot Graphs
plt.plot(years, santacruz_mortgage_ratio, color= 'green', label = "Santa Cruz, CA")
plt.plot(years, sanjose_mortgage_ratio, color= 'blue', label = "San Jose, CA")
plt.plot(years, sanfran_mortgage_ratio, color= 'red', label = "San Francisco, CA")
plt.plot(years, honolulu_mortgage_ratio, color= 'pink', label = "Urban Honolulu, HI")
plt.plot(years, kahului_mortgage_ratio, color= 'purple', label = "Kahului, HI")

plt.legend(loc="best")

#Add graph title, x and y label and set y limits
plt.title("Least Affordable Cities to Mortgage a House 2010-2018")
plt.ylim((min(clean_top5_mortgage["2018 Mortgage to Income Ratio"])-.2), (max(clean_top5_mortgage["2018 Mortgage to Income Ratio"])+.1))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\LeastAffordable_Mortgage.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Mortgage to Income Ratio, bottom 5 by City (Least Expensive)
# In Midland, Mortgage Payment of homes are 14% of the average income
bottom5_mortgage = march_mortgage_clean.sort_values(by=['2018_03'], ascending=True).head()

bottom5_mortgage.round(2)

# Change the name of the columns-bottom5_ratio
clean_bottom5_mortgage = bottom5_mortgage.rename(columns={"2010_03" : "2010 Mortgage to Income Ratio", "2011_03" : "2011 Mortgage to Income Ratio", \
                           "2012_03" : "2012 Mortgage to Income Ratio", "2013_03" : "2013 Mortgage to Income Ratio", \
                           "2014_03" : "2014 Mortgage to Income Ratio", "2015_03" : "2015 Mortgage to Income Ratio", \
                           "2016_03" : "2016 Mortgage to Income Ratio", "2017_03" : "2017 Mortgage to Income Ratio", \
                           "2018_03" : "2018 Mortgage to Income Ratio"})

clean_bottom5_mortgage.round(2)

#Set Index
index_bottom5_mortgage = clean_bottom5_mortgage.set_index("RegionName")

index_bottom5_mortgage.round(2)

# Filter the data for bottom 5 cities with highest Mortgage to Income Ratio
# Filter the Data for Midland
midland_mortgage_ratio = index_bottom5_mortgage.loc["Midland, TX", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

# Filter the Data for Trenton
trenton_mortgage_ratio = index_bottom5_mortgage.loc["Trenton, NJ", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

# Filter the Data for Fairbanks
fairbanks_mortgage_ratio = index_bottom5_mortgage.loc["Fairbanks, AK", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

# Filter the Data for Minneapolis
minneapolis_mortgage_ratio = index_bottom5_mortgage.loc["Minneapolis-St Paul, MN", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]

# Filter the Data for California-Lexington Park
cal_lexington_mortgage_ratio = index_bottom5_mortgage.loc["California-Lexington Park, MD", ["2010 Mortgage to Income Ratio", "2011 Mortgage to Income Ratio", "2012 Mortgage to Income Ratio", \
                                "2013 Mortgage to Income Ratio", "2014 Mortgage to Income Ratio", "2015 Mortgage to Income Ratio", \
                                "2016 Mortgage to Income Ratio", "2017 Mortgage to Income Ratio", "2018 Mortgage to Income Ratio"]]


index_bottom5_mortgage.round(2)

#Plot Graphs
plt.plot(years, midland_mortgage_ratio, color= 'green', label = "Midland, NJ")
plt.plot(years, trenton_mortgage_ratio, color= 'blue', label = "Trenton, NJ")
plt.plot(years, fairbanks_mortgage_ratio, color= 'red', label = "Fairbanks, AK")
plt.plot(years, minneapolis_mortgage_ratio, color= 'pink', label = "Minneapolis-St Paul, MN")
plt.plot(years, cal_lexington_mortgage_ratio, color= 'purple', label = "California-Lexington Park, MD")

plt.legend(loc="best")

#Add graph title, x and y label and set y limits
plt.title("Most Affordable Cities to Mortgage a House 2010-2018")
plt.ylim((min(clean_bottom5_mortgage["2018 Mortgage to Income Ratio"])-.1), (max(clean_bottom5_mortgage["2018 Mortgage to Income Ratio"])+.1))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\MostAffordable_Mortgage.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Income Level

# %%
#Plot Graphs for top 5 and bottom 5 income levels $75k or higher
plt.figure(figsize=(9,7))
plt.plot(years, sanjose_income, color= 'black', label = "San Jose, CA")
plt.plot(years, sanfran_income, color= 'blue', label = "San Francisco, CA")
plt.plot(years, washington_income, color= 'gold', label = "Washnigton, DC")
plt.plot(years, stamford_income, color= 'lightskyblue', label = "Stamford, CT")
plt.plot(years, napa_income, color= 'grey', label = "Napa, CA")
plt.plot(years, austin_income, color= 'green', label = "Austin, TX")
plt.plot(years, midland_income, color= 'aqua', label = "Midland, TX")
plt.plot(years, anchorage_income, color= 'red', label = "Anchorage, AK")
plt.plot(years, newyork_income, color= 'pink', label = "New York, NY")
plt.plot(years, kahului_income, color= 'purple', label = "Kahului, HI")

plt.legend(loc="best")

plt.title("Income for cities with 75K median per household or more 2010-2018")
plt.ylim((min(good_income["2018-03"])-25000), (max(good_income["2018-03"])+5000))
plt.xlabel("Years")
plt.ylabel("Income Level")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\MedianIncomePerHousehold.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Housing Affordability

# %%
#Plot Graphs for top 5 and bottom 5 housing price to income ratio 
#For $75k or higher median income per household
plt.figure(figsize=(9,7))
plt.plot(years, santacruz_housing_ratio, color= 'black', label = "Santa Cruz, CA")
plt.plot(years, sanjose_housing_ratio, color= 'blue', label = "San Jose, CA")
plt.plot(years, sanfran_housing_ratio, color= 'gold', label = "San Francisco, CA")
plt.plot(years, honolulu_housing_ratio, color= 'lightskyblue', label = "Honolulu, HI")
plt.plot(years, kahului_housing_ratio, color= 'grey', label = "Kahului, HI")
plt.plot(years, midland_housing_ratio, color= 'green', label = "Midland, TX")
plt.plot(years, trenton_housing_ratio, color= 'aqua', label = "Trenton, NJ")
plt.plot(years, fairbanks_housing_ratio, color= 'red', label = "Fairbanks, AK")
plt.plot(years, minneapolis_housing_ratio, color= 'pink', label = "Minneapolis-St Paul, MN")
plt.plot(years, cal_lex_housing_ratio, color= 'purple', label = "California-Lexington Park, MD")

plt.legend(loc="best")

plt.title("Affordability Index to Buy a House 2010-2018")
plt.ylim((min(clean_bottom5_housing_ratio["2018 Ratio"])-1), (max(clean_top5_housing_ratio["2018 Ratio"])+2))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\AffordabilityBuy.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Rent Affordability

# %%
#Plot Graphs for top 5 and bottom 5 Rent to income ratio 
#For $75k or higher median income per household
plt.figure(figsize=(9,7))
plt.plot(years, santacruz_rent_ratio, color= 'black', label = "Santa Cruz, CA")
plt.plot(years, santarosa_rent_ratio, color= 'blue', label = "Santa Rosa, CA")
plt.plot(years, sanfran_rent_ratio, color= 'gold', label = "San Francisco, CA")
plt.plot(years, sandiego_rent_ratio, color= 'lightskyblue', label = "San Diego, CA")
plt.plot(years, newyork_rent_ratio, color= 'grey', label = "New York, NY")
plt.plot(years, minneapolis_rent_ratio, color= 'green', label = "Minneapolis-St Paul, MN")
plt.plot(years, washington_rent_ratio, color= 'aqua', label = "Washington, DC")
plt.plot(years, fairbanks_rent_ratio, color= 'red', label = "Fairbanks, AK")
plt.plot(years, manchester_rent_ratio, color= 'pink', label = "Manchester, NH")
plt.plot(years, baltimore_rent_ratio, color= 'purple', label = "Baltimore, MD")

plt.legend(loc="best")

plt.title("Affordability Index to Rent a House 2010-2018")
plt.ylim((min(clean_bottom5_rent["2018 Rent to Income Ratio"])-.05), (max(clean_top5_rent["2018 Rent to Income Ratio"])+.1))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\AffordabilityRent.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Mortgage Affordability

# %%
#Plot Graphs for top 5 and bottom 5 Mortgage to income ratio 
#For $75k or higher median income per household
plt.figure(figsize=(9,7))
index_bottom5_mortgage.round(2)
plt.plot(years, santacruz_mortgage_ratio, color= 'black', label = "Santa Cruz, CA")
plt.plot(years, sanjose_mortgage_ratio, color= 'blue', label = "San Jose, CA")
plt.plot(years, sanfran_mortgage_ratio, color= 'gold', label = "San Francisco, CA")
plt.plot(years, honolulu_mortgage_ratio, color= 'lightskyblue', label = "Urban Honolulu, HI")
plt.plot(years, kahului_mortgage_ratio, color= 'grey', label = "Kahului, HI")
plt.plot(years, midland_mortgage_ratio, color= 'green', label = "Midland, NJ")
plt.plot(years, trenton_mortgage_ratio, color= 'aqua', label = "Trenton, NJ")
plt.plot(years, fairbanks_mortgage_ratio, color= 'red', label = "Fairbanks, AK")
plt.plot(years, minneapolis_mortgage_ratio, color= 'pink', label = "Minneapolis-St Paul, MN")
plt.plot(years, cal_lexington_mortgage_ratio, color= 'purple', label = "California-Lexington Park, MD")

plt.legend(loc="best")

plt.title("Affordability Index to Mortgage a House 2010-2018")
plt.ylim((min(clean_bottom5_mortgage["2018 Mortgage to Income Ratio"])-.1), (max(clean_top5_mortgage["2018 Mortgage to Income Ratio"])+.2))
plt.xlabel("Years")
plt.ylabel("Housing Affordablity Index")
plt.grid()

# Save Figure
# bbox_inches="tight" includes text when figure is saved
plt.savefig("Images\AffordabilityIndex_Mortgage.png", bbox_inches="tight")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Location1 = [(37.338208, -121.886329), (37.77493, -122.419416), (38.907192, -77.036871), (38.502469, -122.265389), 
             (41.05343, -73.538734),
             (42.36, -71.059), (34.28, -119.29), (47.61, -122.33), (38.44, -122.71), (40.01, -105.27), (21.31, -157.86), 
             (38.26, -76.46), (36.97, -122.03), (44.22, -74.76), (43.00, -71.45), (38.10, -122.26), (32.72, -117.16),
            (39.74, -104.99), (44.98, -93.27), (39.29, -76.61), (64.84, -147.72), (20.89, -156.47), (40.71, -74.01),
            (61.22, -149.90), (32.00, -102.08), (30.27, -97.94)]
# weights1 = [(121388.69900),(105089.13310),(101670.89510), (92947.39091), (90300.24882), (87859.35), (84114)
#             ,(84056), (83587), (83394), (82258), (82084), (81944), (80838), (80217), (79219), (78670), (78631), (78224), 
#             (78202), (78188), (77774), (77408), (77007), (76410), (75383)]

weights1 = good_income['2018-03']

# figure_layout = {
#     'width': '200px',
#     'height': '200px',
#     'border': '1px solid black',
#     'padding': '1px',
#     'margin': '1 auto 1 auto'
# }


# fig = gmaps.figure(layout=figure_layout)

# # # Plot Heatmap
# fig = gmaps.figure(map_type='SATELLITE')

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(Location1, weights=weights1, point_radius=5, max_intensity=100)

# # # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig

# #fig.show()
# # plt.savefig('../RealEstate_Project1/heatmap.png', dpi=150)



fig = gmaps.figure()
markers = gmaps.marker_layer(Location1)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
